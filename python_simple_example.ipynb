# %% [markdown]
# # Using Python for Simple Procedures

# %% [markdown]
# This simple notebook shows a simple exercise of downloading a time series, plotting it and getting descriptive statistics.

# %%
import yfinance as yf
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## Downloading and Describing Tesla Stocks from Yahoo Finance

# %%
tesla = yf.download('TSLA', '2010-01-01', '2023-01-14')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
# 2023-01-10  121.070000  122.760002  114.919998  118.849998  118.849998
# 2023-01-11  122.089996  125.949997  120.510002  123.220001  123.220001
# 2023-01-12  122.559998  124.129997  117.000000  123.559998  123.559998
# 2023-01-13  116.550003  122.629997  115.599998  122.400002  122.400002
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
plot1 = tesla.Close.plot()

plot1.set(title = "$TSLA Close Price from 2010 to the present",
       xlabel = "Dates", 
       ylabel = "Close Price")

plt.show()

# %%
tesla.Close.describe()
# Out:
# count    3159.000000
# mean       58.973267
# std        95.441048
# min         1.053333
# 25%         9.033333
# 50%        16.273333
# 75%        24.788000
# max       409.970001
# Name: Close, dtype: float64

# %% [markdown]
# ## Elon Musk in the Joe Rogan Podcast
#
# On 2018-09-06, Elon Musk did an interview in the Joe Rogan Podcast and smoked marihuana live, which make the Close Price for the Tesla Stock to fall after appearing in all the finance news.
#
# MSNBC description of the event:
#
# "Tesla stock plunged 9 percent on Friday after a bizarre podcast in which CEO Elon Musk smoked weed and sipped whiskey, and two high-profile executives abruptly announced they were leaving the company."
#
# https://www.youtube.com/watch?v=1rS8fFbW57o

# %%
tesla_rogan = yf.download('TSLA', '2018-09-05', '2018-09-14')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tesla_rogan
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-09-05  19.003332  19.118668  18.478666  18.716000  18.716000  115812000
# 2018-09-06  18.986668  19.411333  18.591999  18.730000  18.730000  112212000
# 2018-09-07  17.340000  17.889999  16.816668  17.549334  17.549334  337378500
# 2018-09-10  18.217333  19.068666  18.066668  19.033333  19.033333  214252500
# 2018-09-11  18.631332  18.799999  18.236668  18.629333  18.629333  137550000
# 2018-09-12  18.762667  19.500000  18.576668  19.369333  19.369333  150231000
# 2018-09-13  19.201332  19.666668  19.011999  19.297333  19.297333   95104500

# %%
plot2 = tesla_rogan.Close.plot(marker = 'o')

plot2.set(title = "$TSLA Close Price during the week of his interview with Joe Rogan",
       xlabel = "Dates", 
       ylabel = "Close Price")

plt.show()

# %%
tesla_rogan.Close.describe()
# Out:
# count     7.000000
# mean     18.760666
# std       0.608323
# min      17.549334
# 25%      18.672667
# 50%      18.730000
# 75%      19.165333
# max      19.369333
# Name: Close, dtype: float64

# %% [markdown]
# ## Multiple Line Plots
#
# ---

# %% [markdown]
# Selected from: https://finance.yahoo.com/news/10-stocks-elon-musk-put-110036170.html

# %%
tesla = yf.download('TSLA', '2018-01-01', '2023-01-14')
paypal = yf.download('PYPL', '2018-01-01', '2023-01-14')
mod = yf.download('MOD', '2018-05-01', '2023-01-14')
etsy = yf.download('ETSY', '2018-01-01', '2023-01-14')
gamestop = yf.download('OTGLY', '2018-01-01', '2023-01-14')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tesla.Close.plot(label = "Tesla")
paypal.Close.plot(label = "Paypal")
mod.Close.plot(label = "Modine Manufacturing")
etsy.Close.plot(label = "Etsy")
gamestop.Close.plot(label = "Gamestop")

plt.xlabel("Close Price")
plt.ylabel("Dates")
plt.title('Plotting Multiple Stocks related to Elon Musk')

plt.legend()

plt.show()
